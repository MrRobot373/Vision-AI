# %%
# !pip install kaggle


# !mkdir -p ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d awsaf49/coco-2017-dataset
import zipfile
with zipfile.ZipFile("coco-2017-dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("coco-2017-dataset")
# Out:
# ...
# 100% 25.0G/25.0G [04:26<00:00, 90.9MB/s]
# 100% 25.0G/25.0G [04:26<00:00, 101MB/s]

# %%
# !pip install ultralytics
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image
Image("/content/coco-2017-dataset/coco2017/test2017/000000000057.jpg")

# %%
# !yolo predict model=yolov8n.pt source="/content/coco-2017-dataset/coco2017/test2017/000000000057.jpg"
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/coco-2017-dataset/coco2017/test2017/000000000057.jpg: 448x640 1 person, 1 sports ball, 1 tennis racket, 751.4ms
# Speed: 40.6ms preprocess, 751.4ms inference, 10.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install ultralytics
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image
Image("/content/coco-2017-dataset/coco2017/test2017/000000000001.jpg")

# %%
# !yolo predict model=yolov8n.pt source="/content/coco-2017-dataset/coco2017/test2017/000000000001.jpg"
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/coco-2017-dataset/coco2017/test2017/000000000001.jpg: 480x640 1 car, 1 train, 1 truck, 1 parking meter, 519.0ms
# Speed: 19.2ms preprocess, 519.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
